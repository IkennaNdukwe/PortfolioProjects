# %%
import pandas as pd 
from sqlalchemy.engine import create_engine

# %%
# %load_ext sql

# %%
engine = create_engine('mysql://root:P@ssword1@localhost/covid')

# %%
# %sql select * from deaths limit 5
# Out:
#  * mysql://root:***@localhost/covid
# 5 rows affected.
# [('AFG', 'Asia', 'Afghanistan', '2/24/2020', 39835428, 5, 5, None, None, None, None, 0.126, 0.126, None, None, None, None, None, None, None, None, None, None, None, None, '\r'),
#  ('AFG', 'Asia', 'Afghanistan', '2/25/2020', 39835428, 5, 0, None, None, None, None, 0.126, 0.0, None, None, None, None, None, None, None, None, None, None, None, None, '\r'),
#  ('AFG', 'Asia', 'Afghanistan', '2/26/2020', 39835428, 5, 0, None, None, None, None, 0.126, 0.0, None, None, None, None, None, None, None, None, None, None, None, None, '\r'),
#  ('AFG', 'Asia', 'Afghanistan', '2/27/2020', 39835428, 5, 0, None, None, None, None, 0.126, 0.0, None, None, None, None, None, None, None, None, None, None, None, None, '\r'),
#  ('AFG', 'Asia', 'Afghanistan', '2/28/2020', 39835428, 5, 0, None, None, None, None, 0.126, 0.0, None, None, None, None, None, None, None, None, None, None, None, None, '\r')]

# %%
nigeria = %sql select * from deaths where location = 'Nigeria' limit 5
# Out:
#  * mysql://root:***@localhost/covid
# 5 rows affected.

# %%
nigeria
# Out:
# [('NGA', 'Africa', 'Nigeria', '2/28/2020', 211400704, 1, 1, None, None, None, None, 0.005, 0.005, None, None, None, None, None, None, None, None, None, None, None, None, '\r'),
#  ('NGA', 'Africa', 'Nigeria', '2/29/2020', 211400704, 1, 0, None, None, None, None, 0.005, 0.0, None, None, None, None, None, None, None, None, None, None, None, None, '\r'),
#  ('NGA', 'Africa', 'Nigeria', '3/1/2020', 211400704, 1, 0, None, None, None, None, 0.005, 0.0, None, None, None, None, None, None, None, None, None, None, None, None, '\r'),
#  ('NGA', 'Africa', 'Nigeria', '3/2/2020', 211400704, 1, 0, None, None, None, None, 0.005, 0.0, None, None, None, None, None, None, None, None, None, None, None, None, '\r'),
#  ('NGA', 'Africa', 'Nigeria', '3/3/2020', 211400704, 1, 0, None, None, None, None, 0.005, 0.0, None, None, None, None, None, None, None, None, None, None, None, None, '\r')]

# %%
# %%sql
#
# select location, date, total_deaths from deaths limit 5
# Out:
#  * mysql://root:***@localhost/covid
# 5 rows affected.
# [('Afghanistan', '2/24/2020', None),
#  ('Afghanistan', '2/25/2020', None),
#  ('Afghanistan', '2/26/2020', None),
#  ('Afghanistan', '2/27/2020', None),
#  ('Afghanistan', '2/28/2020', None)]

# %%
df = pd.read_sql('select * from vaccinations limit 5', conn)

# %%
df
# Out:
#   iso_code continent     location       date new_tests total_tests  \
# 0      AFG      Asia  Afghanistan  2/24/2020      None        None
# 1      AFG      Asia  Afghanistan  2/25/2020      None        None
# 2      AFG      Asia  Afghanistan  2/26/2020      None        None
# 3      AFG      Asia  Afghanistan  2/27/2020      None        None
# 4      AFG      Asia  Afghanistan  2/28/2020      None        None
#
#   total_tests_per_thousand new_tests_per_thousand new_tests_smoothed  \
# 0                     None                   None               None
# 1                     None                   None               None
# 2                     None                   None               None
# 3                     None                   None               None
# 4                     None                   None               None
#
#   new_tests_smoothed_per_thousand  ... female_smokers male_smokers  \
# 0                            None  ...           None         None
# ...

# %%
engine.dispose()
