# %%
import pandas as pd 
from sqlalchemy.engine import create_engine

# %%
engine = create_engine('mysql://user:password@localhost/world')

# %%
df = pd.read_sql('select * from asia limit 5', engine)

df.head()
# Out:
#   Code                  Name Continent                     Region  \
# 0  AFG           Afghanistan      Asia  Southern and Central Asia
# 1  ARE  United Arab Emirates      Asia                Middle East
# 2  ARM               Armenia      Asia                Middle East
# 3  AZE            Azerbaijan      Asia                Middle East
# 4  BGD            Bangladesh      Asia  Southern and Central Asia
#
#    SurfaceArea  IndepYear  Population  LifeExpectancy      GNP   GNPOld  \
# 0     652090.0       1919    22720000            45.9   5976.0      NaN
# 1      83600.0       1971     2441000            74.1  37966.0  36846.0
# 2      29800.0       1991     3520000            66.4   1813.0   1627.0
# 3      86600.0       1991     7734000            62.9   4127.0   4100.0
# 4     143998.0       1971   129155000            60.2  32852.0  31966.0
#
#                              LocalName      GovernmentForm  \
# 0                Afganistan/Afqanestan     Islamic Emirate
# ...

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %config SqlMagic.autocommit=False

# %%
# %sql mysql://root:P@ssword1@localhost/world

# %%
result = %sql select name, population, lifeexpectancy from asia limit 5
# Out:
#  * mysql://root:***@localhost/world
# 5 rows affected.

# %%
result
# Out:
# [('Afghanistan', 22720000, Decimal('45.9')),
#  ('United Arab Emirates', 2441000, Decimal('74.1')),
#  ('Armenia', 3520000, Decimal('66.4')),
#  ('Azerbaijan', 7734000, Decimal('62.9')),
#  ('Bangladesh', 129155000, Decimal('60.2'))]

# %%
df = result.DataFrame()

# %%
df
# Out:
#                    name  population lifeexpectancy
# 0           Afghanistan    22720000           45.9
# 1  United Arab Emirates     2441000           74.1
# 2               Armenia     3520000           66.4
# 3            Azerbaijan     7734000           62.9
# 4            Bangladesh   129155000           60.2

# %%
# %sql select * from africa limit 5
# Out:
#  * mysql://root:***@localhost/world
# 5 rows affected.
# [('AGO', 'Angola', 'Africa', 'Central Africa', Decimal('1246700.00'), 1975, 12878000, Decimal('38.3'), Decimal('6648.00'), Decimal('7984.00'), 'Angola', 'Republic', 'JosÃ© Eduardo dos Santos', 56, 'AO'),
#  ('BDI', 'Burundi', 'Africa', 'Eastern Africa', Decimal('27834.00'), 1962, 6695000, Decimal('46.2'), Decimal('903.00'), Decimal('982.00'), 'Burundi/Uburundi', 'Republic', 'Pierre Buyoya', 552, 'BI'),
#  ('BEN', 'Benin', 'Africa', 'Western Africa', Decimal('112622.00'), 1960, 6097000, Decimal('50.2'), Decimal('2357.00'), Decimal('2141.00'), 'BÃ©nin', 'Republic', 'Mathieu KÃ©rÃ©kou', 187, 'BJ'),
#  ('BFA', 'Burkina Faso', 'Africa', 'Western Africa', Decimal('274000.00'), 1960, 11937000, Decimal('46.7'), Decimal('2425.00'), Decimal('2201.00'), 'Burkina Faso', 'Republic', 'Blaise CompaorÃ©', 549, 'BF'),
# ...

# %%
# %%sql
#
# select name, population, lifeexpectancy from africa
# where region = 'Western Africa'
# Out:
#  * mysql://root:***@localhost/world
# 17 rows affected.
# [('Benin', 6097000, Decimal('50.2')),
#  ('Burkina Faso', 11937000, Decimal('46.7')),
#  ('CÃ´te dÂ’Ivoire', 14786000, Decimal('45.2')),
#  ('Cape Verde', 428000, Decimal('68.9')),
#  ('Ghana', 20212000, Decimal('57.4')),
#  ('Guinea', 7430000, Decimal('45.6')),
#  ('Gambia', 1305000, Decimal('53.2')),
#  ('Guinea-Bissau', 1213000, Decimal('49.0')),
#  ('Liberia', 3154000, Decimal('51.0')),
#  ('Mali', 11234000, Decimal('46.7')),
#  ('Mauritania', 2670000, Decimal('50.8')),
#  ('Niger', 10730000, Decimal('41.3')),
#  ('Nigeria', 111506000, Decimal('51.6')),
#  ('Senegal', 9481000, Decimal('62.2')),
#  ('Saint Helena', 6000, Decimal('76.8')),
#  ('Sierra Leone', 4854000, Decimal('45.3')),
#  ('Togo', 4629000, Decimal('54.7'))]

# %%
engine.dispose() #close all connections
